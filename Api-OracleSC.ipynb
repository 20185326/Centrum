# %%
import requests
import time

def realizar_solicitud():
    url = 'http://3.80.63.126:8000/enviar-correos-previo/'
    data = {
    }
    response = requests.post(url, json=data)
    if response.status_code == 200:
        pass
    else:
        print("Error al realizar la solicitud POST. Código de estado:", response.status_code)

def ejecutar_solicitudes():
    for i in range(15):
        for j in range(15):
            realizar_solicitud()
            # Espera 5 minutos antes de la próxima solicitud
        print("Envio nro: ",i)
        time.sleep(300)
# Llama a la función para ejecutar las solicitudes
ejecutar_solicitudes()
# Out:
# Envio nro:  0
# Envio nro:  1
# Envio nro:  2
# Envio nro:  3
# Envio nro:  4
# Envio nro:  5
# Envio nro:  6
# Envio nro:  7
# Envio nro:  8
# Envio nro:  9
# Envio nro:  10
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connectionpool.py:416, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415     else:
# --> 416         conn.request(method, url, **httplib_request_kw)
#     418 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     419 # legitimately able to close the connection after sending a valid response.
#     420 # With this behaviour, the received response is still readable.
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~\anaconda3\envs\ventas_env\lib\http\client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\envs\ventas_env\lib\http\client.py:1302, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1301     body = _encode(body, 'body')
# -> 1302 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\ventas_env\lib\http\client.py:1251, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1250     raise CannotSendHeader()
# -> 1251 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\envs\ventas_env\lib\http\client.py:1011, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1010 del self._buffer[:]
# -> 1011 self.send(msg)
#    1013 if message_body is not None:
#    1014
#    1015     # create a consistent interface to message_body
#
# File ~\anaconda3\envs\ventas_env\lib\http\client.py:951, in HTTPConnection.send(self, data)
#     950 if self.auto_open:
# --> 951     self.connect()
#     952 else:
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000029E91909F70>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connectionpool.py:799, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797     e = ProtocolError("Connection aborted.", e)
# --> 799 retries = retries.increment(
#     800     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     801 )
#     802 retries.sleep()
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='3.80.63.126', port=8000): Max retries exceeded with url: /enviar-correos-previo/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000029E91909F70>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[28], line 22
#      20         time.sleep(300)
#      21 # Llama a la función para ejecutar las solicitudes
# ---> 22 ejecutar_solicitudes()
#
# Cell In[28], line 17, in ejecutar_solicitudes()
#      15 for i in range(15):
#      16     for j in range(15):
# ---> 17         realizar_solicitud()
#      18         # Espera 5 minutos antes de la próxima solicitud
#      19     print("Envio nro: ",i)
#
# Cell In[28], line 8, in realizar_solicitud()
#       5 url = 'http://3.80.63.126:8000/enviar-correos-previo/'
#       6 data = {
#       7 }
# ----> 8 response = requests.post(url, json=data)
#       9 if response.status_code == 200:
#      10     pass
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\requests\adapters.py:622, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     618     if isinstance(e.reason, _SSLError):
#     619         # This branch is for urllib3 v1.22 and later.
#     620         raise SSLError(e, request=request)
# --> 622     raise ConnectionError(e, request=request)
#     624 except ClosedPoolError as e:
#     625     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='3.80.63.126', port=8000): Max retries exceeded with url: /enviar-correos-previo/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000029E91909F70>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))

# %%
import requests
import pandas as pd
import openpyxl
# URL de la solicitud
url = "https://cang.fa.us2.oraclecloud.com/crmRestApi/resources/11.13.18.05/setupSalesCatalogs"

# Parámetros de la solicitud
params = {
    'fields':'ProductGroupReferenceNumber,ProdGroupId,ProdGroupName,CTRFechadeinicio_c,CreationDate',
    'q': 'CTREstado_c=Activo',
    'onlyData': 'true',
    'limit': '400'
}

# Encabezados de la solicitud
headers = {
    'Authorization': 'Basic QUNUVUFMSVpBREFUT1M6UXNsdGExMjM='
}

# Realizar la solicitud GET
response = requests.get(url, params=params, headers=headers)
def convert_date_format(date_str):
    date_parts = date_str.split("T")[0].split("-")
    return "-".join([date_parts[0], date_parts[1], date_parts[2]])
# Convertir la respuesta JSON en un DataFrame de pandas
data = response.json()["items"]
df = pd.DataFrame(data)

# Aplicar la función convert_date_format a la columna "LastUpdateDate"
df["CreationDate"] = df["CreationDate"].apply(convert_date_format)

# Guardar el DataFrame en un archivo Excel
nombre_archivo = "informacion_catalogos.xlsx"
df.to_excel(nombre_archivo, index=False)

print("Datos guardados en", nombre_archivo)
# Out:
# Datos guardados en informacion_catalogos.xlsx

# %%
import requests

# URL de la solicitud
url = "https://cang.fa.us2.oraclecloud.com/crmRestApi/resources/11.13.18.05/leads"

# Parámetros de la solicitud
params = {
    'q': 'CTRProductoAsociado_Id_c=300000089986291',
    'onlyData': 'true',
    'limit': '10',
   'fields': 'LeadId,CTRNumDocumento_c,Rank,CTRFechaClasificacionIntermediaLead_c,StatusCode'
}

# Encabezados de la solicitud
headers = {
    'Authorization': 'Basic QUNUVUFMSVpBREFUT1M6UXNsdGExMjM='
}

# Realizar la solicitud GET
response = requests.get(url, params=params, headers=headers)

# Imprimir el código de estado de la respuesta
print("Código de estado:", response)

# Imprimir el contenido de la respuesta si es necesario
for element in response.json()["items"]:
    if element["Rank"]=="WARM":
        print(element)
        print("====")
# Out:
# Código de estado: <Response [200]>
# {'LeadId': 300000091520539, 'CTRNumDocumento_c': '75546089', 'Rank': 'WARM', 'CTRFechaClasificacionIntermediaLead_c': '2024-03-26T21:44:40.374+00:00', 'StatusCode': 'CONVERTED'}
# ====

# %%
import requests

# URL de la solicitud
url = "https://cang.fa.us2.oraclecloud.com/crmRestApi/resources/11.13.18.05/leads"

# Parámetros de la solicitud
params = {
    'q': 'CTRProductoAsociado_Id_c=300000088971085',
    'onlyData': 'true',
    'limit': '10',
    'fields':'LeadId,CTRCorreoDeCliente_c,CTRNumDocumento_c'
}

# Encabezados de la solicitud
headers = {
    'Authorization': 'Basic QUNUVUFMSVpBREFUT1M6UXNsdGExMjM='
}

# Realizar la solicitud GET
response = requests.get(url, params=params, headers=headers)

# Imprimir el código de estado de la respuesta
print("Código de estado:", response)

# Imprimir el contenido de la respuesta si es necesario
print("Contenido de la respuesta:", response.json()["items"])
# Out:
# Código de estado: <Response [200]>
# Contenido de la respuesta: [{'LeadId': 300000093139924, 'CTRCorreoDeCliente_c': 'carla.beraun@pucp.pe', 'CTRNumDocumento_c': '70579324'}, {'LeadId': 300000092544818, 'CTRCorreoDeCliente_c': 'pabloenrique.sosa@outlook.com', 'CTRNumDocumento_c': '47685369'}, {'LeadId': 300000091611375, 'CTRCorreoDeCliente_c': 'alizlaime@gmail.com', 'CTRNumDocumento_c': '40549279'}, {'LeadId': 300000092226216, 'CTRCorreoDeCliente_c': 'jimenagamboa495@gmail.com', 'CTRNumDocumento_c': '73044729'}, {'LeadId': 300000093215440, 'CTRCorreoDeCliente_c': 'maritzam050985@gmail.com', 'CTRNumDocumento_c': '43202234'}, {'LeadId': 300000093141687, 'CTRCorreoDeCliente_c': 'evelyncayetano6@gmail.com', 'CTRNumDocumento_c': '41055103'}, {'LeadId': 300000093283859, 'CTRCorreoDeCliente_c': 'renzogp@hotmail.com', 'CTRNumDocumento_c': '25785796'}, {'LeadId': 300000092983525, 'CTRCorreoDeCliente_c': 'ppintoh90@gmail.com', 'CTRNumDocumento_c': '46524483'}, {'LeadId': 300000091855820, 'CTRCorreoDeCliente_c': 'eduardoyonnel3081@gmail.com', 'CTRNumDocumento_c': '41480080'}, {'LeadId': 300000093538985, 'CTRCorreoDeCliente_c': 'gabriela.tejada.davila@ucsp.edu.pe', 'CTRNumDocumento_c': '71516985'}]

# %%
import requests

# URL de la solicitud para obtener los productos
url_products = "https://cang.fa.us2.oraclecloud.com/crmRestApi/resources/11.13.18.05/setupSalesCatalogs"

# Encabezados de la solicitud para obtener los productos
headers_products = {
    'Authorization': 'Basic QUNUVUFMSVpBREFUT1M6UXNsdGExMjM='
}

# Parámetros de la solicitud para obtener los productos
params_products = {
    'q': 'CTREstado_c=Activo',
    'fields': 'ProdGroupId,ProdGroupName,CreationDate',
    'onlyData': 'true',
    'limit': '1000'
}

# Realizar la solicitud GET para obtener los productos
response_products = requests.get(url_products, params=params_products, headers=headers_products)
response_products.raise_for_status()  # Verifica errores en la solicitud

# URL de la solicitud para obtener los detalles de los leads asociados a los productos
url_leads = "https://cang.fa.us2.oraclecloud.com/crmRestApi/resources/11.13.18.05/leads"

# Encabezados de la solicitud para obtener los detalles de los leads
headers_leads = {
    'Authorization': 'Basic QUNUVUFMSVpBREFUT1M6UXNsdGExMjM='
}

size = 0

# Función para obtener todos los leads con paginación
def fetch_all_leads(product_id):
    all_leads = []
    offset = 0
    limit = 500  # Establece el límite que puedes manejar

    while True:
        params_leads = {
            'q': f'CTRProductoAsociado_Id_c={product_id}',
            'onlyData': 'true',
            'limit': limit,
            'offset': offset,
            'fields': 'LeadId'
        }
        response_leads = requests.get(url_leads, params=params_leads, headers=headers_leads)
        response_leads.raise_for_status()  # Verifica errores en la solicitud

        leads_data = response_leads.json()
        all_leads.extend(leads_data['items'])

        # Verifica si hay más datos para obtener
        if not leads_data.get('hasMore'):
            break

        # Incrementa el offset para la siguiente solicitud
        offset += limit

    return all_leads

# Iterar sobre cada producto y obtener los detalles de los leads asociados
for product in response_products.json()["items"]:
    if product["ProdGroupId"] == 300000088894985:
        print(product["ProdGroupId"])
        all_leads = fetch_all_leads(product["ProdGroupId"])
        print(f"Cantidad total de leads asociados: {len(all_leads)}")
        print(all_leads)
        size += len(all_leads)
# Out:
# 300000088894985
# Cantidad total de leads asociados: 920
# [{'LeadId': 300000091561540}, {'LeadId': 300000091884440}, {'LeadId': 300000093053352}, {'LeadId': 300000091859757}, {'LeadId': 300000091860774}, {'LeadId': 300000091862468}, {'LeadId': 300000092009691}, {'LeadId': 300000093137817}, {'LeadId': 300000092810342}, {'LeadId': 300000091860826}, {'LeadId': 300000092210725}, {'LeadId': 300000092176707}, {'LeadId': 300000093057875}, {'LeadId': 300000093062350}, {'LeadId': 300000091591754}, {'LeadId': 300000092223422}, {'LeadId': 300000093185934}, {'LeadId': 300000093185937}, {'LeadId': 300000093136316}, {'LeadId': 300000091756501}, {'LeadId': 300000091825021}, {'LeadId': 300000092939521}, {'LeadId': 300000093072714}, {'LeadId': 300000092967965}, {'LeadId': 300000091653647}, {'LeadId': 300000