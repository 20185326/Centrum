# %%
import requests

# Define la URL de tu servidor
url = 'http://54.160.199.176:8000/enviar-correos-previo/'  # Asegúrate de que sea la dirección correcta

# Define los datos que deseas enviar en el cuerpo de la solicitud POST
data = {
    # Aquí puedes colocar los datos que deseas enviar al servidor
}

# Realiza la solicitud POST
response = requests.post(url, json=data)
print(response.json())
# Verifica el código de estado de la respuesta
if response.status_code == 200:
    print("Solicitud POST exitosa.")
else:
    print("Error al realizar la solicitud POST. Código de estado:", response.status_code)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\envs\ventas_env\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...
